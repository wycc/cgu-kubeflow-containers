# %% [markdown]
# # Introduction
#
# All packages installed in the base environment will be lost after reboot.
#
# In order to keep the installed package, we need to create another conda environment under the home directory.
#
# Here is the steps.

# %%
# !conda create -n pytorch python=3.11 pip ipykernel -y

# %% [markdown]
# After installation, please refer to the following figure

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Remember to switch environments

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can add as many packages as you want to the environment.

# %%
pip install \
  torch==2.0.0+cu118 \
  torchvision==0.15.0+cu118 \
  torchaudio==2.0.0 \
  --index-url https://download.pytorch.org/whl/cu118

# %%
pip install \
  jupyterlab_tensorboard_pro \
  tensorboard==2.13.0 \
  matplotlib \
  RISE \
  ipyvolume \
  gdown \
  tqdm \
  opencv-python

# %% [markdown]
# After all packages are installed, we need to restart the notebook to activate the environment in the kubeflow notebook list UI.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After reboot, you should be able to see a new environemnt become available to use the new environment.

# %% [markdown]
# ![image.png](attachment:image.png)
