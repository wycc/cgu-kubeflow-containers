# %% [markdown]
# # Introduction
#
# All packages installed in the base environment will be lost after reboot.
#
# In order to keep the installed package, we need to create another conda environment under the home directory.
#
# Here is the steps.

# %%
# !conda create -n pytorch python=3.11 ipykernel=6.21.2 torch=1.13.1 torchvision=0.14.1  torchaudio==0.13.1 jupyterlab_tensorboard_pro tensorboard==2.13.0 matplotlib RISE ipyvolume gdown tqdm opencv-python

# %% [markdown]
# You can add as many packages as you wat to the environment. After all packages are installed, we nedd to restart the notebook to activate the environment in the kubeflow notebook list UI.

# %% [markdown]
# ![image.png](attachment:25a97659-c9a1-4be4-8c92-e3d9b62184e4.png)

# %% [markdown]
# After reboot, you should be able to see a new environemnt become available to use the new environment.

# %% [markdown]
# ![image.png](attachment:62e622ab-8ee7-4a5f-950e-7901eff3d97c.png)
